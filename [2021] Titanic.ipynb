# %%
# %matplotlib inline


import pandas as pd
import seaborn as sns

df = pd.read_csv('datas/titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dict(df['Age'].value_counts())
# Out:
# {24.0: 30,
#  22.0: 27,
#  18.0: 26,
#  19.0: 25,
#  30.0: 25,
#  28.0: 25,
#  21.0: 24,
#  25.0: 23,
#  36.0: 22,
#  29.0: 20,
#  32.0: 18,
#  27.0: 18,
#  35.0: 18,
#  26.0: 18,
#  16.0: 17,
#  31.0: 17,
#  20.0: 15,
#  33.0: 15,
#  23.0: 15,
#  34.0: 15,
#  39.0: 14,
#  17.0: 13,
#  42.0: 13,
#  40.0: 13,
#  45.0: 12,
#  38.0: 11,
#  50.0: 10,
#  2.0: 10,
#  4.0: 10,
#  47.0: 9,
#  44.0: 9,
#  48.0: 9,
#  54.0: 8,
#  9.0: 8,
#  1.0: 7,
#  51.0: 7,
#  52.0: 6,
#  14.0: 6,
#  3.0: 6,
#  49.0: 6,
#  41.0: 6,
#  37.0: 6,
#  15.0: 5,
#  43.0: 5,
#  58.0: 5,
#  11.0: 4,
#  62.0: 4,
#  60.0: 4,
#  8.0: 4,
#  56.0: 4,
#  5.0: 4,
#  46.0: 3,
#  65.0: 3,
#  7.0: 3,
#  6.0: 3,
#  61.0: 3,
#  55.0: 2,
#  28.5: 2,
#  71.0: 2,
#  59.0: 2,
#  63.0: 2,
#  0.83: 2,
#  30.5: 2,
#  70.0: 2,
#  57.0: 2,
#  0.75: 2,
#  13.0: 2,
#  10.0: 2,
#  64.0: 2,
#  40.5: 2,
#  32.5: 2,
#  45.5: 2,
#  20.5: 1,
#  24.5: 1,
#  0.67: 1,
#  14.5: 1,
#  0.92: 1,
#  74.0: 1,
#  34.5: 1,
#  80.0: 1,
#  12.0: 1,
# ...

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
Age = df.set_index('Age')
Age.sort_values(by ='Fare', ascending= False)
# Out:
#       PassengerId  Survived  Pclass                                Name  \
# Age
# 35.0          259         1       1                    Ward, Miss. Anna
# 35.0          738         1       1              Lesurer, Mr. Gustave J
# 36.0          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 23.0           89         1       1          Fortune, Miss. Mabel Helen
# 19.0           28         0       1      Fortune, Mr. Charles Alexander
# ...           ...       ...     ...                                 ...
# NaN           634         0       1       Parr, Mr. William Henry Marsh
# NaN           414         0       2      Cunningham, Mr. Alfred Fleming
# 38.0          823         0       1     Reuchlin, Jonkheer. John George
# NaN           733         0       2                Knight, Mr. Robert J
# NaN           675         0       2          Watson, Mr. Ennis Hastings
#
#          Sex  SibSp  Parch    Ticket      Fare        Cabin Embarked
# Age
# ...

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
Survived = df.loc[df['Survived'] == 1]
Survived['Pclass'].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
sns.violinplot(data=Survived, x='Age')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df.corr()['Survived'].sort_values(ascending = False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
sns.violinplot(data=df, x= 'Sex', y='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>
