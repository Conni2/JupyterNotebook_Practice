# %%
import pandas as pd
titanic = pd.read_table('train.csv',sep=',')
titanic = titanic.dropna()
corr = titanic.corr(method = 'pearson')
corr = corr[corr.Survived !=1]
corr
import matplotlib.pyplot as plt
corr = corr.drop(['PassengerId'], axis ='rows')
corr['Survived'].plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# #null 값 확인
# *db*.isnull().sum() = null 개수 출력
#
# #null 값 제거
# *db*.dropna()
#
# #피어슨 상관계수
# *db*.corr(method= 'pearson)
#
# --------------------------------------
#
# # matplotlib 선언
# import matplotlib.pyplot as plt
#
# #원하는 요소만 뽑아서 보기
# corr['Survived'].plot()
#
# #필요 없는 요소 제거하기
# corr = corr.drop(['지우고 싶은 요소'], axis ='rows')
#
# #그래프 유형 변경
# corr['Survived'].plot.**bar()**
